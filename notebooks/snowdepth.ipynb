# %%
# %matplotlib widget
import pandas
import matplotlib.pyplot as plt
import matplotlib.dates as dates

# %%
df = pandas.read_csv('202210300306CUES_query.csv')
df['MeasDateTime']= pandas.to_datetime(df['MeasDateTime'])
#df.set_index('MeasDateTime', inplace=True)

# %%
fig = plt.figure(figsize=(8, 4.5), dpi=200)
ax = fig.add_subplot()

df.plot(ax=ax, grid=True, marker='x', rot=90)
ax.xaxis.set_major_locator(dates.DayLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%Y-%m-%d'))
ax.set_ylabel('Snow Depth in cm')
ax.set_xlabel('')

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
